# %% [markdown]
# SENTIMENT ANALYSIS ON IMDB REVIEW DATASET

# %%
# importing requried libraries and packages

import pandas as pd
import numpy as np

# %%
# Loading Data
df = pd.read_csv("IMDB Dataset.csv")

# %%
# Basic exploration 
df.head()
df.shape
# Out:
# (50000, 2)

# %%
# Looking for null values
df.isnull().sum() # No null values can be seen
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
# dropping duplicate values if any 
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (49582, 2)

# %%
# Initialising new dataframe
df_1 = df
df_1.shape
# Out:
# (49582, 2)

# %% [markdown]
# ## TEXT PRE PROCESSING

# %% [markdown]
# ### 1. CONVERTING EVERYTHING TO LOWERCASE

# %%
df_1['review'] = df_1['review'].str.lower()

# %% [markdown]
# ### 2. Removing URLS

# %%
# Removing URLS using Regex
import re

def remove_url(text):
    text = re.sub(r"http\S+" ,"", text) # (Pattern, replacment, string)
    return text
df_1['review'] = df_1['review'].apply(remove_url)

# %% [markdown]
# ### 3. Removing Punctions

# %%
def remove_punct(text):
    text = re.sub(r"[A-Za_z0-9\s]" ,"", text) # (Pattern, replacment, string) A-Z a_z 0-9 \s
    return text
    

df_1['review'] = df_1['review'].apply(remove_punct)

# %% [markdown]
# ### 4. Removing HTML Tags

# %%
def remove_html(text):
    text = re.sub(r"<.*?>" ,"", text) # (Pattern, replacment, string) 
    return text
    

df_1['review'] = df_1['review'].apply(remove_html)

# %% [markdown]
# ### 5. Removing Stop Words

# %%
import nltk

nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")

# SAMPLE WORD CHECK
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Purvesh
# [nltk_data]     Bhave\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to C:\Users\Purvesh
# [nltk_data]     Bhave\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Purvesh
# [nltk_data]     Bhave\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
# DEVELOPING MODEL 

# model evalutaions
